# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohan-69108/project-1/blob/main/Resume_project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/drive/MyDrive/Data set/Student_Performance.csv")

# %%
df.head(5)
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
df.shape
# Out:
# (10000, 6)

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced
# ...

# %%
y
# Out:
# 0       91.0
# 1       65.0
# 2       45.0
# 3       36.0
# 4       66.0
#         ...
# 9995    23.0
# 9996    58.0
# 9997    74.0
# 9998    95.0
# 9999    64.0
# Name: Performance Index, Length: 10000, dtype: float64

# %%
df.isnull().mean()*100   #no null values
# Out:
# Hours Studied                       0.0
# Previous Scores                     0.0
# Extracurricular Activities          0.0
# Sleep Hours                         0.0
# Sample Question Papers Practiced    0.0
# Performance Index                   0.0
# dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
x_train
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 8856              9               82                        Yes            7
# 1545              7               76                         No            8
# 8136              9               47                         No            5
# 7768              3               60                        Yes            9
# 7782              9               88                         No            9
# ...             ...              ...                        ...          ...
# 1099              5               87                        Yes            5
# 2514              6               56                         No            4
# 6637              2               98                         No            8
# 2575              8               45                         No            8
# 7336              4               93                        Yes            6
#
#       Sample Question Papers Practiced
# ...

# %%
x_test
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 7878              3               48                        Yes            7
# 3224              8               41                         No            9
# 1919              6               92                        Yes            6
# 4432              3               85                         No            9
# 4835              7               90                        Yes            7
# ...             ...              ...                        ...          ...
# 9073              8               97                         No            8
# 8584              2               41                         No            5
# 5390              9               48                         No            7
# 5092              1               55                        Yes            7
# 2964              7               76                        Yes            7
#
#       Sample Question Papers Practiced
# ...

# %%
y_train
# Out:
# 8856    83.0
# 1545    71.0
# 8136    47.0
# 7768    40.0
# 7782    84.0
#         ...
# 1099    73.0
# 2514    44.0
# 6637    78.0
# 2575    41.0
# 7336    75.0
# Name: Performance Index, Length: 8000, dtype: float64

# %%
y_test
# Out:
# 7878    26.0
# 3224    34.0
# 1919    80.0
# 4432    62.0
# 4835    83.0
#         ...
# 9073    91.0
# 8584    15.0
# 5390    44.0
# 5092    31.0
# 2964    67.0
# Name: Performance Index, Length: 2000, dtype: float64

# %%
#PERFORMING EDA

# %%
df.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %%
sns.histplot(df["Hours Studied"],kde=True,color="green")
# Out:
# <Axes: xlabel='Hours Studied', ylabel='Count'>

# %%
sns.boxplot(df["Hours Studied"],color="green")  #OBSERVATION: no outliers
# Out:
# <Axes: ylabel='Hours Studied'>

# %%
sns.histplot(df["Previous Scores"],kde=True,color="red")
# Out:
# <Axes: xlabel='Previous Scores', ylabel='Count'>

# %%
sns.boxplot(df["Previous Scores"],color="red") #OBSERVATION: no outliers
# Out:
# <Axes: ylabel='Previous Scores'>

# %%
sns.histplot(df["Sleep Hours"],kde=True,color="blue")
# Out:
# <Axes: xlabel='Sleep Hours', ylabel='Count'>

# %%
sns.boxplot(df["Sleep Hours"],color="blue")
# Out:
# <Axes: ylabel='Sleep Hours'>

# %%
sns.histplot(df["Sample Question Papers Practiced"],kde=True,color="yellow")
# Out:
# <Axes: xlabel='Sample Question Papers Practiced', ylabel='Count'>

# %%
sns.boxplot(df["Sample Question Papers Practiced"],color="yellow")
# Out:
# <Axes: ylabel='Sample Question Papers Practiced'>

# %%
sns.histplot(df["Performance Index"],kde=True,color="orange")
# Out:
# <Axes: xlabel='Performance Index', ylabel='Count'>

# %%
sns.boxplot(df["Performance Index"],color="orange")
# Out:
# <Axes: ylabel='Performance Index'>

# %%
sns.countplot(x='Extracurricular Activities', data=df)
plt.show()

# %%
corr_coef=df["Hours Studied"].corr(df["Sleep Hours"])
corr_coef

# %%
numerical_fet = x.select_dtypes(include=['number']).columns

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(x[numerical_fet].values, i) for i in range(x[numerical_fet].shape[1])]
vif["features"] = x[numerical_fet].columns

# %%
vif
# Out:
#    VIF Factor                          features
# 0    4.248789                     Hours Studied
# 1    9.866227                   Previous Scores
# 2    9.736833                       Sleep Hours
# 3    3.340441  Sample Question Papers Practiced

# %%
df['Extracurricular Activities'] = df['Extracurricular Activities'].map({'Yes': 1, 'No': 0})
correlation_matrix=df.corr()

# %%
correlation_matrix
# Out:
#                                   Hours Studied  Previous Scores  \
# Hours Studied                          1.000000        -0.012390
# Previous Scores                       -0.012390         1.000000
# Extracurricular Activities             0.003873         0.008369
# Sleep Hours                            0.001245         0.005944
# Sample Question Papers Practiced       0.017463         0.007888
# Performance Index                      0.373730         0.915189
#
#                                   Extracurricular Activities  Sleep Hours  \
# Hours Studied                                       0.003873     0.001245
# Previous Scores                                     0.008369     0.005944
# Extracurricular Activities                          1.000000    -0.023284
# Sleep Hours                                        -0.023284     1.000000
# Sample Question Papers Practiced                    0.013103     0.003990
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
# Out:
# <Axes: >

# %%
df.head(5)
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              7               99                           1            9
# 1              4               82                           0            4
# 2              8               51                           1            7
# 3              5               52                           1            5
# 4              7               75                           0            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
x_train
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 8856              9               82                        Yes            7
# 1545              7               76                         No            8
# 8136              9               47                         No            5
# 7768              3               60                        Yes            9
# 7782              9               88                         No            9
# ...             ...              ...                        ...          ...
# 1099              5               87                        Yes            5
# 2514              6               56                         No            4
# 6637              2               98                         No            8
# 2575              8               45                         No            8
# 7336              4               93                        Yes            6
#
#       Sample Question Papers Practiced
# ...

# %%
print(x_train.columns)
print(x_test.columns)
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced'],
#       dtype='object')
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced'],
#       dtype='object')

# %%
x_train['Extracurricular Activities'] = x_train['Extracurricular Activities'].map({'Yes': 1, 'No': 0})

# %%
x_train
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 8856              9               82                           1            7
# 1545              7               76                           0            8
# 8136              9               47                           0            5
# 7768              3               60                           1            9
# 7782              9               88                           0            9
# ...             ...              ...                         ...          ...
# 1099              5               87                           1            5
# 2514              6               56                           0            4
# 6637              2               98                           0            8
# 2575              8               45                           0            8
# 7336              4               93                           1            6
#
# ...

# %%
x_test['Extracurricular Activities'] = x_test['Extracurricular Activities'].map({'Yes': 1, 'No': 0})

# %%
x_test
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 7878              3               48                           1            7
# 3224              8               41                           0            9
# 1919              6               92                           1            6
# 4432              3               85                           0            9
# 4835              7               90                           1            7
# ...             ...              ...                         ...          ...
# 9073              8               97                           0            8
# 8584              2               41                           0            5
# 5390              9               48                           0            7
# 5092              1               55                           1            7
# 2964              7               76                           1            7
#
# ...

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([2.85352109, 1.01959723, 0.59483017, 0.48314352, 0.1977199 ])

# %%
lr.intercept_
# Out:
# -34.17752765121658

# %%
y_pred=lr.predict(x_test)

# %%
y_pred
# Out:
# array([28.09141683, 35.39557867, 80.43795479, ..., 45.01315301,
#        30.31243483, 68.64738321])

# %%
y_test.values
# Out:
# array([26., 34., 80., ..., 44., 31., 67.])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
# Out:
# MAE 1.5926720612039293

# %%
print("MSE",mean_squared_error(y_test,y_pred))
# Out:
# MSE 4.070278591652593

# %%
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RMSE 2.0174931453793326

# %%
print("r2",r2_score(y_test,y_pred))
R2=r2_score(y_test,y_pred)
# Out:
# r2 0.9890954655668953

# %%
#adjusted r square
1-(((1-R2)*(1000-1)/(1000-1-5)))
# Out:
# 0.9890406137840326
